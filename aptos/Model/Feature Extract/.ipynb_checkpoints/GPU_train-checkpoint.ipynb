# %%
import os
import torch
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import torchvision
from torch import nn,optim
from torch.nn import functional as F
from torchvision import transforms 
from torchvision import models as m
from torch.utils.data import DataLoader
import torch
from PIL import Image
import matplotlib.pyplot as plt
import random
import numpy as np
import pandas as pd
import time
import datetime
import gc  #garbage collector
import json
from timm.models.vision_transformer import VisionTransformer
from torchinfo import summary
import cv2

# %%
torch.cuda.manual_seed(1412)
torch.cuda.manual_seed_all(1412)
torch.manual_seed(420)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(torch.cuda.is_available())
# Out:
# True

# %%
vgg16_bn_ =m.vgg16_bn() 
resnet18_ = m.resnet18()

# %%
class MyNet3(nn.Module):
    def __init__(self,in_features=3):
        super().__init__()
#         self.conv1=nn.Sequential( BasicConv2d(in_ = in_features,out_=32,kernel_size=3,stride=1,padding=1)
#                                  ,BasicConv2d(in_ = 32,out_=64,kernel_size=3,stride=1,padding=1)
#                                 ,nn.MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False))
#         self.conv1=nn.Sequential( BasicConv2d(in_ = in_features,out_=32,kernel_size=3,stride=1,padding=1)
#                                  ,BasicConv2d(in_ = 32,out_=64,kernel_size=3,stride=1,padding=1)
#                                 ,nn.MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False))
    
#         self.conv1 = nn.Sequential(BasicConv2d_two(in_features,32,64,kernel_size=3,stride=1,padding=1))
        self.conv1 = nn.Sequential(BasicConv2d_two( in_features, 32, 32,kernel_size=3,stride=1,padding=1))
        self.conv2 = nn.Sequential(BasicConv2d_two( 32, 64, 64,kernel_size=3,stride=1,padding=1))
#         self.block1=vgg16_bn_.features[7:14]
        self.block1=resnet18_.layer2
        self.block2=resnet18_.layer3
        self.avgpool=vgg16_bn_.avgpool
        self.classifer=nn.Sequential( nn.Linear(12544, 256, bias=True)
                                     ,nn.BatchNorm1d(256)
                                     ,nn.Dropout(p=0.5)
                                     ,nn.Linear(256,128, bias=True)
                                     ,nn.BatchNorm1d(128)
                                     ,nn.Dropout(p=0.5)
                                    )
        self.fc = nn.Linear(128,4)
        
    def forward(self,x):
        x = self.conv1(x)
        x= self.conv2(x)
        x= self.block1(x)
        x = self.block2(x)
        x = self.avgpool(x)
        x=x.view(-1,12544)
        x = self.classifer(x)
        x = self.fc(x)
        return F.log_softmax(x, dim=1)

# %%
class BasicConv2d_two(nn.Module):
    def __init__(self,in_,out_,f1,**kwargs):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_,out_, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(out_),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_, f1, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(f1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
          )
            
            
    def forward(self,x):
        x = self.conv1(x)
        return x

# %%
net3 = MyNet3()

# %%
summary(net3,input_size=(10,3,224,224),depth=3,device="cpu")
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MyNet3                                   [10, 4]                   --
# ├─Sequential: 1-1                        [10, 32, 112, 112]        --
# │    └─BasicConv2d_two: 2-1              [10, 32, 112, 112]        --
# │    │    └─Sequential: 3-1              [10, 32, 112, 112]        9,696
# ├─Sequential: 1-2                        [10, 64, 56, 56]          --
# │    └─BasicConv2d_two: 2-2              [10, 64, 56, 56]          --
# │    │    └─Sequential: 3-2              [10, 64, 56, 56]          55,680
# ├─Sequential: 1-3                        [10, 128, 28, 28]         --
# │    └─BasicBlock: 2-3                   [10, 128, 28, 28]         --
# │    │    └─Conv2d: 3-3                  [10, 128, 28, 28]         73,728
# │    │    └─BatchNorm2d: 3-4             [10, 128, 28, 28]         256
# │    │    └─ReLU: 3-5                    [10, 128, 28, 28]         --
# │    │    └─Conv2d: 3-6                  [10, 128, 28, 28]         147,456
# │    │    └─BatchNorm2d: 3-7             [10, 128, 28, 28]         256
# │    │    └─Sequential: 3-8              [10, 128, 28, 28]         8,448
# │    │    └─ReLU: 3-9                    [10, 128, 28, 28]         --
# │    └─BasicBlock: 2-4                   [10, 128, 28, 28]         --
# │    │    └─Conv2d: 3-10                 [10, 128, 28, 28]         147,456
# │    │    └─BatchNorm2d: 3-11            [10, 128, 28, 28]         256
# │    │    └─ReLU: 3-12                   [10, 128, 28, 28]         --
# │    │    └─Conv2d: 3-13                 [10, 128, 28, 28]         147,456
# │    │    └─BatchNorm2d: 3-14            [10, 128, 28, 28]         256
# │    │    └─ReLU: 3-15                   [10, 128, 28, 28]         --
# ├─Sequential: 1-4                        [10, 256, 14, 14]         --
# │    └─BasicBlock: 2-5                   [10, 256, 14, 14]         --
# │    │    └─Conv2d: 3-16                 [10, 256, 14, 14]         294,912
# │    │    └─BatchNorm2d: 3-17            [10, 256, 14, 14]         512
# │    │    └─ReLU: 3-18                   [10, 256, 14, 14]         --
# │    │    └─Conv2d: 3-19                 [10, 256, 14, 14]         589,824
# │    │    └─BatchNorm2d: 3-20            [10, 256, 14, 14]         512
# │    │    └─Sequential: 3-21             [10, 256, 14, 14]         33,280
# │    │    └─ReLU: 3-22                   [10, 256, 14, 14]         --
# │    └─BasicBlock: 2-6                   [10, 256, 14, 14]         --
# │    │    └─Conv2d: 3-23                 [10, 256, 14, 14]         589,824
# │    │    └─BatchNorm2d: 3-24            [10, 256, 14, 14]         512
# │    │    └─ReLU: 3-25                   [10, 256, 14, 14]         --
# │    │    └─Conv2d: 3-26                 [10, 256, 14, 14]         589,824
# │    │    └─BatchNorm2d: 3-27            [10, 256, 14, 14]         512
# │    │    └─ReLU: 3-28                   [10, 256, 14, 14]         --
# ├─AdaptiveAvgPool2d: 1-5                 [10, 256, 7, 7]           --
# ├─Sequential: 1-6                        [10, 128]                 --
# │    └─Linear: 2-7                       [10, 256]                 3,211,520
# │    └─BatchNorm1d: 2-8                  [10, 256]                 512
# │    └─Dropout: 2-9                      [10, 256]                 --
# │    └─Linear: 2-10                      [10, 128]                 32,896
# │    └─BatchNorm1d: 2-11                 [10, 128]                 256
# │    └─Dropout: 2-12                     [10, 128]                 --
# ├─Linear: 1-7                            [10, 4]                   516
# ==========================================================================================
# Total params: 5,936,356
# Trainable params: 5,936,356
# Non-trainable params: 0
# Total mult-adds (G): 20.01
# ==========================================================================================
# Input size (MB): 2.01
# Forward/backward pass size (MB): 891.19
# Params size (MB): 23.75
# Estimated Total Size (MB): 916.94
# ==========================================================================================

# %%
def IterOnce(net,criterion,opt,x,y):
    """
    对模型进行一次迭代的函数
    
    net: 实例化后的架构
    criterion: 损失函数
    opt: 优化算法
    x: 这一个batch中所有的样本
    y: 这一个batch中所有样本的真实标签
    """
    sigma = net.forward(x)
    loss = criterion(sigma,y)
    loss.backward()
    opt.step()
    opt.zero_grad(set_to_none=True) #比起设置梯度为0，让梯度为None会更节约内存
    yhat = torch.max(sigma,1)[1]
    correct = torch.sum(yhat == y)
    return correct,loss

# %%
def TestOnce(net,criterion,x,y):
    """
    对一组数据进行测试并输出测试结果的函数
    
    net: 经过训练后的架构
    criterion：损失函数
    x：要测试的数据的所有样本
    y：要测试的数据的真实标签
    """
    #对测试，一定要阻止计算图追踪
    #这样可以节省很多内存，加速运算
    with torch.no_grad(): 
        sigma = net.forward(x)
        loss = criterion(sigma,y)
        yhat = torch.max(sigma,1)[1]
        correct = torch.sum(yhat == y)
    return correct,loss

# %%
def fit_test(net,batchdata,criterion,opt,epochs,tol,modelname,PATH):
    """
    对模型进行训练，并在每个epoch后输出训练集和测试集上的准确率/损失
    以实现对模型的监控
    实现模型的保存
    
    参数说明：
    net: 实例化后的网络
    batchdata：使用Dataloader分割后的训练数据
    testdata：使用Dataloader分割后的测试数据
    criterion：所使用的损失函数
    opt：所使用的优化算法
    epochs：一共要使用完整数据集epochs次
    tol：提前停止时测试集上loss下降的阈值，连续5次loss下降不超过tol就会触发提前停止
    modelname：现在正在运行的模型名称，用于保存权重时作为文件名
    PATH：将权重文件保存在path目录下
    
    """
    
    SamplePerEpoch = batchdata.dataset.__len__() #整个epoch里有多少个样本
    allsamples = SamplePerEpoch*epochs
    trainedsamples = 0
    trainlosslist = []
    
#     early_stopping = EarlyStopping(tol=tol)
    highestacc = None
    
    for epoch in range(1,epochs+1):
        net.train()
        correct_train = 0
        loss_train = 0
        for batch_idx, (x, y) in enumerate(batchdata):
             #non_blocking 非阻塞=True，表示允许多个线程同时占用一个资源
            #一般来说，一段代码/数据占用一部分计算资源时，该资源是不对其他代码/数据开放的
            #此时被占用的资源叫做临界资源，正在运行的代码/数据被叫做临界区
            #设置non_blocking=True，相当于允许多个代码在临界资源上运行
            #可以加速运算
            x = x.to(device,non_blocking=True)
            y = y.to(device,non_blocking=True).view(x.shape[0])
           
            correct, loss = IterOnce(net,criterion,opt,x,y)
            trainedsamples += x.shape[0]
            loss_train += loss
            correct_train += correct
            
            if (batch_idx+1) % 125 == 0:
                #现在进行到了哪个epoch
                #现在训练到了多少个样本
                #总共要训练多少个样本
                #现在的训练的样本占总共需要训练的样本的百分比
                print('Epoch{}:[{}/{}({:.0f}%)]'.format(epoch
                                                       ,trainedsamples
                                                       ,allsamples
                                                       ,100*trainedsamples/allsamples))
            
        TrainAccThisEpoch = float(correct_train*100)/SamplePerEpoch
        TrainLossThisEpoch = float(loss_train)/SamplePerEpoch #平均每个样本上的损失
        trainlosslist.append(TrainLossThisEpoch)
    
       #清理GPU内存
        del x,y,correct,loss,correct_train,loss_train
        gc.collect()
        torch.cuda.empty_cache()
      
    
#         #每次训练完一个epoch，就在测试集上验证一下模型现在的效果
#         net.eval()
#         loss_test = 0
#         correct_test = 0
#         loss_test = 0
#         TestSample = testdata.dataset.__len__()

#         for x,y in testdata:
#             x = x.to(device,non_blocking=True)
#             y = y.to(device,non_blocking=True).view(x.shape[0])
           
#             correct, loss = TestOnce(net,criterion,x,y)
#             loss_test += loss
#             correct_test += correct

#         TestAccThisEpoch = float(correct_test * 100)/TestSample
#         TestLossThisEpoch = float(loss_test )/TestSample
#         testlosslist.append(TestLossThisEpoch)
        
#         del x,y,correct,loss,correct_test, loss_test
#         gc.collect()
#         torch.cuda.empty_cache()
        
        #对每一个epoch，打印训练和测试的结果
        #训练集上的损失，测试集上的损失，训练集上的准确率，测试集上的准确率
        print("\t Train Loss:{:.6f}, Train Acc:{:.3f}%".format(TrainLossThisEpoch
                                                            ,TrainAccThisEpoch
                                                                                 ))
        
        #如果测试集准确率出现新高/测试集loss出现新低，那我会保存现在的这一组权重
        if highestacc == None: #首次进行测试
            highestacc = TrainAccThisEpoch
        if highestacc < TrainAccThisEpoch:
            highestacc = TrainAccThisEpoch
            torch.save(net.state_dict(),os.path.join(PATH,modelname+".pt"))
#             torch.save(net.state_dict(), os.path.join(PATH, str(modelname) + ".pt"))
            print("\t Weight Saved")
        
#         #提前停止
#         early_stop = early_stopping(TestLossThisEpoch)
#         if early_stop == "True":
#             break
            
    print("Complete")
    return trainlosslist

# %%
def read_split_data(root: str, val_rate: float = 0.3):
    random.seed(420)  # 保证随机结果可复现
    assert os.path.exists(root), "dataset root: {} does not exist.".format(root)

    # 遍历文件夹，一个文件夹对应一个类别
    flower_class = [cla for cla in os.listdir(root) if os.path.isdir(os.path.join(root, cla))]
    # 排序，保证各平台顺序一致
    flower_class.sort()
    # 生成类别名称以及对应的数字索引
    class_indices = dict((k, v) for v, k in enumerate(flower_class))
    json_str = json.dumps(dict((val, key) for key, val in class_indices.items()), indent=4)
    with open('class_indices.json', 'w') as json_file:
        json_file.write(json_str)

    train_images_path = []  # 存储训练集的所有图片路径
    train_images_label = []  # 存储训练集图片对应索引信息
    val_images_path = []  # 存储验证集的所有图片路径
    val_images_label = []  # 存储验证集图片对应索引信息
    every_class_num = []  # 存储每个类别的样本总数
    supported = [".jpg", ".JPG", ".png", ".PNG"]  # 支持的文件后缀类型
    # 遍历每个文件夹下的文件
    for cla in flower_class:
        cla_path = os.path.join(root, cla)
        # 遍历获取supported支持的所有文件路径
        images = [os.path.join(root, cla, i) for i in os.listdir(cla_path)
                  if os.path.splitext(i)[-1] in supported]
        # 排序，保证各平台顺序一致
        images.sort()
        # 获取该类别对应的索引
        image_class = class_indices[cla]
        # 记录该类别的样本数量
        every_class_num.append(len(images))
        # 按比例随机采样验证样本
#         val_path = random.sample(images, k=int(len(images) * val_rate))

        for img_path in images:
#             if img_path in val_path:  # 如果该路径在采样的验证集样本中则存入验证集
#                 val_images_path.append(img_path)
#                 val_images_label.append(image_class)
#             else:  # 否则存入训练集
            train_images_path.append(img_path)
            train_images_label.append(image_class)

    print("{} images were found in the dataset.".format(sum(every_class_num)))
    print("{} images for training.".format(len(train_images_path)))
   
    assert len(train_images_path) > 0, "number of training images must greater than 0."
  
    

    return train_images_path, train_images_label, val_images_path, val_images_label

# %%
class MyDataSet():
    """自定义数据集"""

    def __init__(self, images_path: list, images_class: list, transform=None):
        self.images_path = images_path
        self.images_class = images_class
        self.transform = transform

    def __len__(self):
        return len(self.images_path)

    def __getitem__(self, item):
        img = Image.open(self.images_path[item])
        # RGB为彩色图片，L为灰度图片
        if img.mode != 'RGB':
            raise ValueError("image: {} isn't RGB mode.".format(self.images_path[item]))
        label = self.images_class[item]

        if self.transform is not None:
            img = self.transform(img)

        return img, label
    
    
    
#     def __getitem__(self, item):
#         img = cv2.imread(self.images_path[item], cv2.IMREAD_GRAYSCALE)
#         if img is None:
#             raise ValueError("Failed to read image: {}".format(self.images_path[item]))
#         label = self.images_class[item]
    
#         if self.transform is not None:
#             img = self.transform(img)
    
#         return img, label
    
    
    
    

    @staticmethod
    def collate_fn(batch):
        # 官方实现的default_collate可以参考
        # https://github.com/pytorch/pytorch/blob/67b7e751e6b5931a9f45274653f4f653a4e6cdf6/torch/utils/data/_utils/collate.py
        images, labels = tuple(zip(*batch))

        images = torch.stack(images, dim=0)
        labels = torch.as_tensor(labels)
        return images, labels

# %%
data_path = "/home/ubuntu/fy/diabetic retinopathy/feature selection/data/seg_VB_tofeature"

# %%
train_images_path, train_images_label, val_images_path, val_images_label = read_split_data(data_path)
# Out:
# 1200 images were found in the dataset.
# 1200 images for training.

# %%
img_size = 224
data_transform = {
        "train": transforms.Compose([transforms.RandomHorizontalFlip(p=0.5),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        "val": transforms.Compose([
#                                  transforms.Resize(int(img_size * 1.143)),
#                                    transforms.CenterCrop(img_size),
                                   transforms.ToTensor(),
                                   transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ])}

# 实例化训练数据集
train_dataset = MyDataSet(images_path=train_images_path,
                              images_class=train_images_label,
                               transform=data_transform["train"]
                         )

# # 实例化验证数据集
# val_dataset = MyDataSet(images_path=val_images_path,
#                             images_class=val_images_label,
#                            transform=data_transform["val"]
#                        )

# %%
def full_procedure(net,epochs,bs,modelname, PATH, lr=0.001,alpha=0.99,gamma=0,wd=0,tol=10**(-5)):
    
    torch.manual_seed(1412)
    
    #分割数据
    batchdata = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=bs,
                                               shuffle=True,
                                               pin_memory=True,
                                               drop_last=True,
                                               collate_fn=train_dataset.collate_fn)

#     testdata =torch.utils.data.DataLoader(val_dataset,
#                                              batch_size=bs,
#                                              drop_last=True,
#                                              shuffle=False,
#                                              pin_memory=True,
                                             
#                                              collate_fn=val_dataset.collate_fn)
    
    #损失函数，优化算法
    criterion = nn.CrossEntropyLoss(reduction="sum") #进行损失函数计算时，最后输出结果的计算模式
    opt = optim.RMSprop(net.parameters(),lr=lr
                        ,alpha=alpha,momentum=gamma,weight_decay=wd)
    
    #训练与测试
    trainloss = fit_test(net,batchdata,criterion,opt,epochs,tol,modelname,PATH)
    
    return trainloss

# %%
#绘图函数
def plotloss(trainloss, testloss):
    plt.figure(figsize=(10, 7))
    plt.plot(trainloss, color="red", label="Trainloss")
    plt.plot(testloss, color="orange", label="Testloss")
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
#实例化
#trainloss, testloss = full_procedure(XXXX)
#plotloss()

# %%
modelname = "MyNet3_0.001_train_2"
torch.manual_seed(420)
model3 = MyNet3()
PATH  ="/home/ubuntu/jupyter notebook/"
# model3.load_state_dict(torch.load("/home/ubuntu/jupyter notebook/MyNet3_0.001_train_2.pt"))
print(modelname)

net = model3.to(device,non_blocking=True)
trainloss3 = full_procedure(model3,200,64,modelname=modelname, PATH=PATH, lr=0.005,alpha=0.99,gamma=0.005,wd=0,tol=10**(-5))
# Out:
# MyNet3_0.001_train_2
# 	 Train Loss:1.618652, Train Acc:35.917%
# 	 Train Loss:1.413058, Train Acc:41.250%
# 	 Weight Saved
# 	 Train Loss:1.336157, Train Acc:43.000%
# 	 Weight Saved
# 	 Train Loss:1.310493, Train Acc:42.167%
# 	 Train Loss:1.322997, Train Acc:43.250%
# 	 Weight Saved
# 	 Train Loss:1.276896, Train Acc:44.333%
# 	 Weight Saved
# 	 Train Loss:1.278285, Train Acc:44.667%
# 	 Weight Saved
# 	 Train Loss:1.271649, Train Acc:44.583%
# 	 Train Loss:1.224963, Train Acc:45.750%
# 	 Weight Saved
# 	 Train Loss:1.266048, Train Acc:44.167%
# 	 Train Loss:1.229549, Train Acc:44.250%
# 	 Train Loss:1.234997, Train Acc:44.917%
# 	 Train Loss:1.234588, Train Acc:45.750%
# 	 Train Loss:1.215238, Train Acc:46.167%
# 	 Weight Saved
# 	 Train Loss:1.219163, Train Acc:46.500%
# 	 Weight Saved
# 	 Train Loss:1.212025, Train Acc:45.750%
# 	 Train Loss:1.177698, Train Acc:47.417%
# 	 Weight Saved
# 	 Train Loss:1.203720, Train Acc:43.667%
# 	 Train Loss:1.172582, Train Acc:46.583%
# 	 Train Loss:1.164686, Train Acc:46.000%
# 	 Train Loss:1.139221, Train Acc:48.417%
# 	 Weight Saved
# 	 Train Loss:1.131857, Train Acc:48.000%
# 	 Train Loss:1.103980, Train Acc:49.583%
# 	 Weight Saved
# 	 Train Loss:1.033752, Train Acc:51.417%
# 	 Weight Saved
# 	 Train Loss:0.980566, Train Acc:56.000%
# 	 Weight Saved
# 	 Train Loss:0.937110, Train Acc:56.417%
# 	 Weight Saved
# 	 Train Loss:0.828165, Train Acc:63.333%
# 	 Weight Saved
# 	 Train Loss:0.724321, Train Acc:66.917%
# 	 Weight Saved
# 	 Train Loss:0.672745, Train Acc:70.667%
# 	 Weight Saved
# 	 Train Loss:0.557869, Train Acc:74.083%
# 	 Weight Saved
# 	 Train Loss:0.496279, Train Acc:78.667%
# 	 Weight Saved
# 	 Train Loss:0.409282, Train Acc:81.250%
# 	 Weight Saved
# 	 Train Loss:0.303918, Train Acc:86.333%
# 	 Weight Saved
# 	 Train Loss:0.257081, Train Acc:86.500%
# 	 Weight Saved
# 	 Train Loss:0.250955, Train Acc:88.083%
# 	 Weight Saved
# 	 Train Loss:0.221398, Train Acc:88.667%
# 	 Weight Saved
# 	 Train Loss:0.118325, Train Acc:92.417%
# 	 Weight Saved
# 	 Train Loss:0.149900, Train Acc:90.583%
# 	 Train Loss:0.146905, Train Acc:91.167%
# 	 Train Loss:0.142171, Train Acc:91.417%
# 	 Train Loss:0.102997, Train Acc:92.667%
# 	 Weight Saved
# 	 Train Loss:0.110335, Train Acc:92.500%
# 	 Train Loss:0.182357, Train Acc:90.000%
# 	 Train Loss:0.084491, Train Acc:93.667%
# 	 Weight Saved
# 	 Train Loss:0.081181, Train Acc:93.167%
# 	 Train Loss:0.064929, Train Acc:93.750%
# 	 Weight Saved
# 	 Train Loss:0.073419, Train Acc:94.167%
# 	 Weight Saved
# 	 Train Loss:0.045586, Train Acc:95.000%
# 	 Weight Saved
# 	 Train Loss:0.081927, Train Acc:93.167%
# 	 Train Loss:0.076261, Train Acc:93.833%
# 	 Train Loss:0.105724, Train Acc:92.333%
# 	 Train Loss:0.044332, Train Acc:94.083%
# 	 Train Loss:0.088567, Train Acc:93.583%
# 	 Train Loss:0.065500, Train Acc:94.583%
# 	 Train Loss:0.083410, Train Acc:93.417%
# 	 Train Loss:0.127858, Train Acc:91.917%
# 	 Train Loss:0.076138, Train Acc:93.333%
# 	 Train Loss:0.053491, Train Acc:94.250%
# 	 Train Loss:0.062941, Train Acc:94.000%
# 	 Train Loss:0.051831, Train Acc:94.167%
# 	 Train Loss:0.039198, Train Acc:95.667%
# 	 Weight Saved
# 	 Train Loss:0.045373, Train Acc:94.667%
# 	 Train Loss:0.019547, Train Acc:95.417%
# 	 Train Loss:0.023800, Train Acc:95.500%
# 	 Train Loss:0.017272, Train Acc:95.500%
# 	 Train Loss:0.032002, Train Acc:95.167%
# 	 Train Loss:0.157869, Train Acc:91.500%
# 	 Train Loss:0.144922, Train Acc:91.083%
# 	 Train Loss:0.053607, Train Acc:94.250%
# 	 Train Loss:0.058952, Train Acc:93.583%
# 	 Train Loss:0.072453, Train Acc:93.750%
# 	 Train Loss:0.027255, Train Acc:94.917%
# 	 Train Loss:0.057859, Train Acc:95.083%
# 	 Train Loss:0.040134, Train Acc:95.000%
# 	 Train Loss:0.032565, Train Acc:95.083%
# 	 Train Loss:0.045539, Train Acc:94.833%
# 	 Train Loss:0.054184, Train Acc:94.667%
# 	 Train Loss:0.061722, Train Acc:94.000%
# 	 Train Loss:0.074792, Train Acc:93.417%
# 	 Train Loss:0.039180, Train Acc:94.667%
# 	 Train Loss:0.027679, Train Acc:95.250%
# 	 Train Loss:0.030068, Train Acc:95.000%
# 	 Train Loss:0.047369, Train Acc:95.083%
# 	 Train Loss:0.057813, Train Acc:94.417%
# 	 Train Loss:0.029735, Train Acc:95.583%
# 	 Train Loss:0.042481, Train Acc:94.833%
# 	 Train Loss:0.063014, Train Acc:94.083%
# 	 Train Loss:0.048574, Train Acc:94.583%
# 	 Train Loss:0.015839, Train Acc:95.750%
# 	 Weight Saved
# 	 Train Loss:0.028488, Train Acc:95.667%
# 	 Train Loss:0.024189, Train Acc:95.333%
# 	 Train Loss:0.044161, Train Acc:94.667%
# 	 Train Loss:0.042553, Train Acc:94.917%
# 	 Train Loss:0.023587, Train Acc:95.167%
# 	 Train Loss:0.094941, Train Acc:93.667%
# 	 Train Loss:0.042204, Train Acc:94.667%
# 	 Train Loss:0.035121, Train Acc:95.000%
# 	 Train Loss:0.038519, Train Acc:94.500%
# 	 Train Loss:0.055361, Train Acc:94.167%
# 	 Train Loss:0.097233, Train Acc:93.583%
# 	 Train Loss:0.065371, Train Acc:94.083%
# 	 Train Loss:0.035892, Train Acc:94.833%
# 	 Train Loss:0.029241, Train Acc:95.250%
# 	 Train Loss:0.009491, Train Acc:95.750%
# 	 Train Loss:0.014827, Train Acc:95.667%
# 	 Train Loss:0.021164, Train Acc:95.583%
# 	 Train Loss:0.033610, Train Acc:95.000%
# 	 Train Loss:0.036606, Train Acc:94.667%
# 	 Train Loss:0.021272, Train Acc:95.667%
# 	 Train Loss:0.018033, Train Acc:95.917%
# 	 Weight Saved
# 	 Train Loss:0.028731, Train Acc:95.167%
# 	 Train Loss:0.008293, Train Acc:95.833%
# 	 Train Loss:0.032042, Train Acc:95.083%
# 	 Train Loss:0.066345, Train Acc:94.500%
# 	 Train Loss:0.044311, Train Acc:95.000%
# 	 Train Loss:0.066807, Train Acc:93.833%
# 	 Train Loss:0.037673, Train Acc:94.917%
# 	 Train Loss:0.046109, Train Acc:94.667%
# 	 Train Loss:0.025548, Train Acc:94.667%
# 	 Train Loss:0.038579, Train Acc:94.917%
# 	 Train Loss:0.026687, Train Acc:94.833%
# 	 Train Loss:0.004472, Train Acc:96.000%
# 	 Weight Saved
# 	 Train Loss:0.027527, Train Acc:95.333%
# 	 Train Loss:0.064245, Train Acc:94.833%
# 	 Train Loss:0.034785, Train Acc:95.083%
# 	 Train Loss:0.020294, Train Acc:95.333%
# 	 Train Loss:0.048188, Train Acc:94.417%
# 	 Train Loss:0.048584, Train Acc:95.167%
# 	 Train Loss:0.040584, Train Acc:94.750%
# 	 Train Loss:0.018898, Train Acc:95.583%
# 	 Train Loss:0.023309, Train Acc:95.500%
# 	 Train Loss:0.007766, Train Acc:95.750%
# 	 Train Loss:0.012434, Train Acc:95.917%
# 	 Train Loss:0.016776, Train Acc:95.667%
# 	 Train Loss:0.031647, Train Acc:95.000%
# 	 Train Loss:0.081437, Train Acc:93.667%
# 	 Train Loss:0.058863, Train Acc:94.583%
# 	 Train Loss:0.040973, Train Acc:94.833%
# 	 Train Loss:0.029657, Train Acc:95.333%
# 	 Train Loss:0.024880, Train Acc:95.417%
# 	 Train Loss:0.009556, Train Acc:95.833%
# 	 Train Loss:0.019866, Train Acc:95.500%
# 	 Train Loss:0.035976, Train Acc:95.333%
# 	 Train Loss:0.004603, Train Acc:95.917%
# 	 Train Loss:0.014702, Train Acc:95.750%
# 	 Train Loss:0.005943, Train Acc:95.833%
# 	 Train Loss:0.004538, Train Acc:96.000%
# 	 Train Loss:0.040916, Train Acc:95.583%
# 	 Train Loss:0.050147, Train Acc:94.667%
# 	 Train Loss:0.043313, Train Acc:94.583%
# 	 Train Loss:0.086153, Train Acc:93.583%
# 	 Train Loss:0.042602, Train Acc:94.583%
# 	 Train Loss:0.015191, Train Acc:95.667%
# 	 Train Loss:0.016496, Train Acc:95.583%
# 	 Train Loss:0.017086, Train Acc:95.667%
# 	 Train Loss:0.026584, Train Acc:95.583%
# 	 Train Loss:0.050626, Train Acc:94.667%
# 	 Train Loss:0.035297, Train Acc:94.917%
# 	 Train Loss:0.011610, Train Acc:95.583%
# 	 Train Loss:0.012623, Train Acc:95.583%
# 	 Train Loss:0.022091, Train Acc:95.583%
# 	 Train Loss:0.003631, Train Acc:95.917%
# 	 Train Loss:0.015127, Train Acc:95.833%
# 	 Train Loss:0.007575, Train Acc:95.750%
# 	 Train Loss:0.055002, Train Acc:94.000%
# 	 Train Loss:0.022697, Train Acc:95.250%
# 	 Train Loss:0.051224, Train Acc:94.333%
# 	 Train Loss:0.036902, Train Acc:95.250%
# 	 Train Loss:0.020121, Train Acc:95.417%
# 	 Train Loss:0.035890, Train Acc:94.833%
# 	 Train Loss:0.018846, Train Acc:95.250%
# 	 Train Loss:0.017922, Train Acc:95.583%
# 	 Train Loss:0.036901, Train Acc:94.750%
# 	 Train Loss:0.033003, Train Acc:95.250%
# 	 Train Loss:0.008314, Train Acc:95.833%
# 	 Train Loss:0.014920, Train Acc:95.500%
# 	 Train Loss:0.017552, Train Acc:95.750%
# 	 Train Loss:0.017671, Train Acc:95.583%
# 	 Train Loss:0.017966, Train Acc:95.583%
# 	 Train Loss:0.022179, Train Acc:95.583%
# 	 Train Loss:0.022024, Train Acc:95.500%
# 	 Train Loss:0.012677, Train Acc:95.667%
# 	 Train Loss:0.008792, Train Acc:95.750%
# 	 Train Loss:0.011728, Train Acc:95.500%
# 	 Train Loss:0.019483, Train Acc:95.750%
# 	 Train Loss:0.046567, Train Acc:94.583%
# 	 Train Loss:0.051550, Train Acc:94.417%
# 	 Train Loss:0.030480, Train Acc:95.083%
# 	 Train Loss:0.018866, Train Acc:95.500%
# 	 Train Loss:0.014766, Train Acc:95.667%
# 	 Train Loss:0.016674, Train Acc:95.833%
# 	 Train Loss:0.011264, Train Acc:95.833%
# 	 Train Loss:0.008419, Train Acc:95.833%
# 	 Train Loss:0.024390, Train Acc:95.667%
# 	 Train Loss:0.028554, Train Acc:95.417%
# 	 Train Loss:0.037024, Train Acc:94.667%
# 	 Train Loss:0.061866, Train Acc:94.417%
# 	 Train Loss:0.034977, Train Acc:95.333%
# 	 Train Loss:0.033104, Train Acc:94.917%
# 	 Train Loss:0.042053, Train Acc:94.917%
# Complete

# %%
torch.cuda.empty_cache()

# %%
gc.collect()
torch.cuda.empty_cache()
